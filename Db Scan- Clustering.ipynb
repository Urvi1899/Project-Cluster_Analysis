# %%
pip install chart-studio
# Out:
# Requirement already satisfied: chart-studio in c:\users\91705\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: plotly in c:\users\91705\anaconda3\lib\site-packages (from chart-studio) (5.6.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\91705\anaconda3\lib\site-packages (from chart-studio) (1.3.4)
# Requirement already satisfied: requests in c:\users\91705\anaconda3\lib\site-packages (from chart-studio) (2.27.1)
# Requirement already satisfied: six in c:\users\91705\anaconda3\lib\site-packages (from chart-studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\91705\anaconda3\lib\site-packages (from plotly->chart-studio) (8.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\91705\anaconda3\lib\site-packages (from requests->chart-studio) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91705\anaconda3\lib\site-packages (from requests->chart-studio) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\91705\anaconda3\lib\site-packages (from requests->chart-studio) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91705\anaconda3\lib\site-packages (from requests->chart-studio) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly=2.7.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: 'plotly=2.7.0'
# Hint: = is not a valid operator. Did you mean == ?

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import plotly as py #For World Map
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('clean_data.csv')
df
# Out:
#       Unnamed: 0  Birth Rate  Business Tax Rate  CO2 Emissions  \
# 0              0       0.020            73.7125        87931.0
# 1              1       0.050            52.1000         9542.0
# 2              2       0.043            71.0875         1617.0
# 3              3       0.027            18.7250         4276.0
# 4              4       0.046            45.4875         1041.0
# ...          ...         ...                ...            ...
# 2699        2699       0.013             0.0000          161.0
# 2700        2700       0.013            46.4000        91118.0
# 2701        2701       0.015            41.9000          737.0
# 2702        2702       0.020            61.9000        91118.0
# 2703        2703       0.011             0.0000           99.0
#
#       Days to Start Business  Energy Usage           GDP  Health Exp % GDP  \
# 0                       13.0       26998.0  5.479006e+10             0.035
# 1                       13.0        7499.0  9.129595e+09             0.034
# 2                       40.0        1983.0  2.359122e+09             0.043
# 3                       40.0        1836.0  5.788312e+09             0.047
# 4                       84.0         765.0  2.610959e+09             0.051
# ...                      ...           ...           ...               ...
# 2699                    40.0          76.0  2.671401e+09             0.033
# 2700                     5.0     2132446.0  1.624460e+13             0.179
# 2701                     7.0       19986.0  5.000435e+10             0.089
# 2702                   144.0       27086.0  3.812862e+11             0.046
# 2703                    16.0          81.0  2.558908e+08             0.120
#
#       Health Exp/Capita  Hours to do Tax  ...  Mobile Phone Usage  \
# 0                  60.0            336.0  ...                 0.0
# 1                  22.0            336.0  ...                 0.0
# 2                  15.0             52.0  ...                 0.0
# 3                 152.0             52.0  ...                 0.1
# 4                  12.0            216.0  ...                 0.0
# ...                 ...              ...  ...                 ...
# 2699             2718.0             52.0  ...                 0.4
# 2700             8895.0            175.0  ...                 1.0
# 2701             1308.0            310.0  ...                 1.5
# 2702              593.0            792.0  ...                 1.0
# 2703              292.0            128.0  ...                 0.3
#
#       Number of Records  Population 0-14  Population 15-64  Population 65+  \
# 0                   1.0            0.342             0.619           0.039
# 1                   1.0            0.476             0.499           0.025
# 2                   1.0            0.454             0.517           0.029
# 3                   1.0            0.383             0.587           0.029
# 4                   1.0            0.468             0.505           0.028
# ...                 ...              ...               ...             ...
# 2699                1.0            0.292             0.637           0.071
# 2700                1.0            0.196             0.667           0.136
# 2701                1.0            0.220             0.639           0.140
# 2702                1.0            0.288             0.652           0.060
# 2703                1.0            0.206             0.641           0.152
#
#       Population Total  Population Urban  Tourism Inbound  Tourism Outbound  \
# 0           31719449.0             0.599     1.020000e+08      1.930000e+08
# 1           13924930.0             0.324     3.400000e+07      1.460000e+08
# 2            6949366.0             0.383     7.700000e+07      5.000000e+07
# 3            1755375.0             0.532     2.270000e+08      2.090000e+08
# 4           11607944.0             0.178     2.300000e+07      3.000000e+07
# ...                ...               ...              ...               ...
# 2699           32427.0             0.911     4.890000e+08      1.400000e+08
# 2700       313873685.0             0.811     2.000920e+11      1.265730e+11
# 2701         3395253.0             0.948     2.222000e+09      1.028000e+09
# 2702        29954782.0             0.889     9.040000e+08      3.202000e+09
# 2703          105275.0             0.949     2.500000e+07      7.000000e+06
#
#                        Country
# 0                      Algeria
# 1                       Angola
# 2                        Benin
# 3                     Botswana
# 4                 Burkina Faso
# ...                        ...
# 2699  Turks and Caicos Islands
# 2700             United States
# 2701                   Uruguay
# 2702             Venezuela, RB
# 2703     Virgin Islands (U.S.)
#
# [2704 rows x 25 columns]

# %%
df = df.drop(['Number of Records'], axis=1)

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
df_norm = norm_func(df.iloc[:,:22])
df_norm
# Out:
#       Unnamed: 0  Birth Rate  Business Tax Rate  CO2 Emissions  \
# 0        0.00000    0.282609           0.217377       0.010610
# 1        0.00037    0.934783           0.153642       0.001151
# 2        0.00074    0.782609           0.209636       0.000194
# 3        0.00111    0.434783           0.055220       0.000515
# 4        0.00148    0.847826           0.134142       0.000125
# ...          ...         ...                ...            ...
# 2699     0.99852    0.130435           0.000000       0.000019
# 2700     0.99889    0.130435           0.136833       0.010995
# 2701     0.99926    0.173913           0.123562       0.000088
# 2702     0.99963    0.282609           0.182542       0.010995
# 2703     1.00000    0.086957           0.000000       0.000011
#
#       Days to Start Business  Energy Usage       GDP  Health Exp % GDP  \
# 0                   0.017316      0.009895  0.003369          0.124424
# 1                   0.017316      0.002746  0.000558          0.119816
# 2                   0.056277      0.000724  0.000141          0.161290
# 3                   0.056277      0.000670  0.000352          0.179724
# 4                   0.119769      0.000278  0.000157          0.198157
# ...                      ...           ...       ...               ...
# 2699                0.056277      0.000025  0.000161          0.115207
# 2700                0.005772      0.781766  1.000000          0.788018
# 2701                0.008658      0.007324  0.003074          0.373272
# 2702                0.206349      0.009927  0.023468          0.175115
# 2703                0.021645      0.000027  0.000012          0.516129
#
#       Health Exp/Capita  Hours to do Tax  ...  Lending Interest  \
# 0              0.005855         0.125193  ...          0.019153
# 1              0.002019         0.125193  ...          0.207056
# 2              0.001312         0.015456  ...          0.010887
# 3              0.015142         0.015456  ...          0.030242
# 4              0.001009         0.078825  ...          0.010887
# ...                 ...              ...  ...               ...
# 2699           0.274177         0.015456  ...          0.010887
# 2700           0.897739         0.062983  ...          0.005645
# 2701           0.131839         0.115147  ...          0.021573
# 2702           0.059661         0.301391  ...          0.032056
# 2703           0.029275         0.044822  ...          0.027218
#
#       Life Expectancy Female  Life Expectancy Male  Mobile Phone Usage  \
# 0                   0.666667              0.588235            0.000000
# 1                   0.166667              0.137255            0.000000
# 2                   0.375000              0.313725            0.000000
# 3                   0.270833              0.235294            0.034483
# 4                   0.270833              0.235294            0.000000
# ...                      ...                   ...                 ...
# 2699                0.854167              0.725490            0.137931
# 2700                0.875000              0.764706            0.344828
# 2701                0.854167              0.725490            0.517241
# 2702                0.812500              0.686275            0.344828
# 2703                0.916667              0.764706            0.103448
#
#       Population 0-14  Population 15-64  Population 65+  Population Total  \
# 0            0.586387          0.377604        0.149378          0.023470
# 1            0.937173          0.065104        0.091286          0.010296
# 2            0.879581          0.111979        0.107884          0.005131
# 3            0.693717          0.294271        0.107884          0.001286
# 4            0.916230          0.080729        0.103734          0.008580
# ...               ...               ...             ...               ...
# 2699         0.455497          0.424479        0.282158          0.000010
# 2700         0.204188          0.502604        0.551867          0.232369
# 2701         0.267016          0.429688        0.568465          0.002500
# 2702         0.445026          0.463542        0.236515          0.022164
# 2703         0.230366          0.434896        0.618257          0.000064
#
#       Population Urban  Tourism Inbound
# 0             0.563181         0.000506
# 1             0.263617         0.000166
# 2             0.327887         0.000381
# 3             0.490196         0.001131
# 4             0.104575         0.000111
# ...                ...              ...
# 2699          0.903050         0.002440
# 2700          0.794118         1.000000
# 2701          0.943355         0.011101
# 2702          0.879085         0.004514
# 2703          0.944444         0.000121
#
# [2704 rows x 22 columns]

# %%
dbscan = DBSCAN(eps=0.7, min_samples=7)
dbscan.fit(df_norm)
# Out:
# DBSCAN(eps=0.7, min_samples=7)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])

# %%
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 2699        0
# 2700       -1
# 2701        0
# 2702        0
# 2703        0
#
# [2704 rows x 1 columns]

# %%
df = pd.concat([df,cl],axis=1)

# %%
df['cluster'].value_counts()
# Out:
#  0    2623
#  2      26
#  1      24
#  3      12
#  4       8
#  5       8
# -1       3
# Name: cluster, dtype: int64
